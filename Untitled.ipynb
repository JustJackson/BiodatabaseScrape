# %%
from collections import Counter
with open("BioModelsDatabase.txt") as input_file:
    wordcount = Counter(input_file.read().split())
    for item in wordcount.most_common(): 
        print("{}\t{}".format(*item))
# Out:
# the	38388
# of	26235
# model	23243
# and	21579
# to	19289
# from	15827
# by	15481
# et	14584
# a	12678
# is	12350
# for	12132
# with	11034
# metabolic	10634
# been	10486
# information	9743
# Human	9710
# GDC	9662
# or	6923
# BioModels	6626
# this	6107
# have	5758
# encoded	5735
# copyright	5709
# on	5671
# more	5644
# was	5633
# under	5525
# all	5515
# Database	5463
# possible	5460
# related	5457
# please	5427
# extent	5426
# public	5424
# cite	5423
# use:	5422
# rights	5422
# dedicated	5421
# domain	5421
# refer	5421
# worldwide.	5420
# law,	5419
# neighbouring	5419
# Please	5419
# Public	5419
# Domain	5419
# CC0	5387
# Dedication	5387
# A	5346
# human	5228
# metabolism	5222
# Syst	5217
# Chelliah	5148
# identified	5144
# at	5111
# hosted	5110
# genome-scale	5101
# has	5060
# automatically	5038
# using	5010
# Metabolic	4957
# genome	4942
# M.,	4938
# through	4929
# where	4925
# via	4901
# generated	4898
# pathway	4896
# accessed	4887
# 43	4877
# modeling.	4876
# release	4870
# ...
